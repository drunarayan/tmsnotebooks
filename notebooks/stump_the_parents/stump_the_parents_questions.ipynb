# %% [markdown]
# ### Questions to stump the parents. This notebook is scret only known to students - NOT PARENTS!!

# %% [markdown]
# 1. What is the value of PI with 9 digits of precision?  ```3.1415925```
# 1. What is the approximate Diameter of the Earth in km  ```12700 km```
# 1. What is the approximate circumference of the Earth in km? ```38000 km```
# 1. How many Earths will fit across the diameter of the Sun? ```100```
# 1. What is the approximate diameter of the Sun? ```1.4 millinn km```
# 1. How many atoms can fit on the head of a very fine needle (about 1 mm)? ```about 10 million or ``` $10^7$ ```atoms```
# 1. If the nucleus of the atom is the size of a pea at the center of St James Cathedral in London where will you find the first electron? ```at the top of the dome. The atom is mostly empty space!```
# 1. This being the case why dont we simply fall through chairs or even the floor we walk on? ```the electron cloud & quantum electro degeneracy. The electrons at the lowest level shell in an atom can only be in 2 states and both are taken```
# 1. What are the colors of the rainbow? ```VIBGYOR
# 1. What has a higher temperature an object emmitting icy blue color or red hot color? ```icy blue color```
# 1. Why is the rainbow (ultimately sunlight) made up of all those colors? ```Sun and all stars (infact everything and everyone) emits light of different wavelenghts (or frequencies) depending on its temperature. Our eyes interpret these wavelenghts as color. Long wavelenghts are Redder and Short wavelenghts are Bluer VIBGYOR```
# 1. Who sang "It's a Wonderful World" at the Kennedy Center with president Obama in the audience? ```John Bapiste```
# 1. What is the 8th number in the Fibonacci Sequence (provide an exact answer)? ```21```
# 1. What is the 11th number in fibo? ```84```
# 1. Give an example of where you might fibonacci numbers in nature? ```sunflowers```
# 1. Give another? ```pine cones```
# 1. How old is the Universe? ```13.7 billion years old 13.7```$*10^9$ ```years old```
# 1. What will the Sun become at the end of its life ```a white dwarf star```
# 1. How old old is the Sun now? ```4.5 ```* $10^9$ ```years old```
# 1. What is a Hydrophyllic moecule?  ```a molecule that likes water```
# 2. 1. What was the procedure we used to measure the size of an atom? ```we formed a monomolecular layer of the Oleic Acid molecule and measured its volume```
# 1. Where can normal distributions be found in nature? ```coin tosses, gendered people heights in a given region, manufacturing errors, age people die```
# 1. if you were to toss a 6-sided die 100 times what is mostlikely be the average of values seen? ```3.5```
# 1. If you want a glider to  make a left turn how will you adjust the rudder on the tail if you are facing forward from the perspective of the plane? ```left```
# 1. If you want a glider to dive how will you adjust the elevator on the tail if you are facing forward from the perspective of the plane? ```down```
